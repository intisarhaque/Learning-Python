# %% [markdown]
# # Singly Linked Lists

# %% [markdown]
# A collection of nodes that form a linear sequence.
#
# Each node has reference to object that is an element of the sequence as well as a reference to the next node of the list.
#
# Going through the node is traversing the list.
#
# Next reference of node known as link/pointer therefor traversing aka link/pointer hopping.
#
# Linked lists have constant time insertions and deletions in any position/comparison. Arrays require O(n) to do same thing.
# They can continue to expand without specifying size ahead of time.
# But to access element in linked list, takes time O(k) to go from head to the kth element. Arrays have constant time to do so.

# %%
from IPython.display import Image
Image(filename="image/Linked.png", width = 400, height = 400)

# %% [markdown]
# ## Inserting to Single

# %% [markdown]
# Linked list doesn't have a fixed size. Uses space proportional to no. of elements.
#
# To create new element at head of list, make new node, set element as new element, set link to previoius head.
#
# Set new head reference to new head.
#
# To create new element at tail of list, make new node, set element, assign link to None, set next reference of old tail to new node.
#
# Set new tail reference to new tail.

# %% [markdown]
# ## Removing from Single

# %% [markdown]
# Removing element from head of linked list is reverse opration of inserting a new head element.
# To do, point head reference to new head element.
#
# Deleting last node is harder?

# %%
class Node(object):
    
    def __init__(self, value):
        
        self.value = value
        self.nextnode = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)
a.nextnode = b
b.nextnode = c

# %%
a.value
# Out:
# 1

# %%
a.nextnode.value
# Out:
# 2

# %% [markdown]
# # Doubly Linked List

# %% [markdown]
# Now our node keeps a reference to node before and after.
#
# Allows O(1)-time update operations (insert/delete).
#
# "Next" to refer to node that follows, "prev" for preceding node.
#
# Add dummy nodes, header and tail, at both ends of list (known as sentinels).

# %% [markdown]
# Inserting and deleting nodes takes place between 2 nodes.
#
# To insert, first you create the node, then point it to the neighbours., and get rid of the next's next link and before's before link.
#
# Deleting involves points the neighbours at eachother then getting rid of the element.

# %%
from IPython.display import Image
Image(filename="image/Doublelinked.png", width = 400, height = 400)

# %%
class DoubleNode(object):
    def __init__(self,value):
        
        self.value = value
        self.next_node = None

# %%
a = DoubleNode(1)
b = DoubleNode(2)
c = DoubleNode(3)

a.next_node = b
b.prev_node = a
b.next_node = c
c.prev_node = b
#c.next_node = a (circular node)

# %%
c.prev_node.value
# Out:
# 2

# %%
# def solution(N):
#     binary = []
#     count = 0
#     maxcount = 0
#     formern = False
#     while N>0:
#         print("N is ", N)
#         binarynum = N%2
#         binary.insert(0,binarynum)
#         print("binary is", binary)
#         if (binarynum==0):
#             count += 1
#         else:
#             print(formern)
#             print("count is", count)
#             print("maxcount is", maxcount)
#             if (count>maxcount) & (formern==True):
#                 maxcount = count
            
#             count = 0
#             formern = True
        
        
        
#         N=N//2

#     print("\n\n\n")
#     print("binary is", binary)
#     print("maxcount is", maxcount)
#     pass

# %%
#solution(72)
